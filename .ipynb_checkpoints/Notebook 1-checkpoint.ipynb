# %%
#imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Information (1).csv')
df.head()
# Out:
#     _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 0  815719226    False   finalized                   3    10/26/15 23:24
# 1  815719227    False   finalized                   3    10/26/15 23:30
# 2  815719228    False   finalized                   3    10/26/15 23:33
# 3  815719229    False   finalized                   3    10/26/15 23:10
# 4  815719230    False   finalized                   3     10/27/15 1:15
#
#    gender  gender:confidence profile_yn  profile_yn:confidence  \
# 0    male             1.0000        yes                    1.0
# 1    male             1.0000        yes                    1.0
# 2    male             0.6625        yes                    1.0
# 3    male             1.0000        yes                    1.0
# 4  female             1.0000        yes                    1.0
#
#           created  ...                                       profileimage  \
# 0    12/5/13 1:48  ...  https://pbs.twimg.com/profile_images/414342229...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20050 entries, 0 to 20049
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   _unit_id               20050 non-null  int64
#  1   _golden                20050 non-null  bool
#  2   _unit_state            20050 non-null  object
#  3   _trusted_judgments     20050 non-null  int64
#  4   _last_judgment_at      20000 non-null  object
#  5   gender                 19953 non-null  object
#  6   gender:confidence      20024 non-null  float64
#  7   profile_yn             20050 non-null  object
#  8   profile_yn:confidence  20050 non-null  float64
#  9   created                20050 non-null  object
#  10  description            16306 non-null  object
#  11  fav_number             20050 non-null  int64
#  12  gender_gold            50 non-null     object
#  13  link_color             20050 non-null  object
# ...

# %%
df.shape
# Out:
# (20050, 26)

# %%
df.corr()
# Out:
#                        _unit_id   _golden  _trusted_judgments  \
# _unit_id               1.000000  0.208055            0.207651
# _golden                0.208055  1.000000            0.998592
# _trusted_judgments     0.207651  0.998592            1.000000
# gender:confidence      0.007918  0.008818            0.009550
# profile_yn:confidence  0.015168  0.005592            0.005543
# fav_number             0.024878  0.003794            0.003851
# retweet_count         -0.004337 -0.000744           -0.000765
# tweet_count           -0.024809 -0.009669           -0.009703
# tweet_id               0.844887 -0.005985           -0.005781
#
#                        gender:confidence  profile_yn:confidence  fav_number  \
# _unit_id                        0.007918               0.015168    0.024878
# _golden                         0.008818               0.005592    0.003794
# _trusted_judgments              0.009550               0.005543    0.003851
# ...

# %%
df.describe()
# Out:
#            _unit_id  _trusted_judgments  gender:confidence  \
# count  2.005000e+04        20050.000000       20024.000000
# mean   8.157294e+08            3.615711           0.882756
# std    6.000801e+03           12.331890           0.191403
# min    8.157192e+08            3.000000           0.000000
# 25%    8.157243e+08            3.000000           0.677800
# 50%    8.157294e+08            3.000000           1.000000
# 75%    8.157345e+08            3.000000           1.000000
# max    8.157580e+08          274.000000           1.000000
#
#        profile_yn:confidence     fav_number  retweet_count   tweet_count  \
# count           20050.000000   20050.000000   20050.000000  2.005000e+04
# mean                0.993221    4382.201646       0.079401  3.892469e+04
# std                 0.047168   12518.575919       2.649751  1.168371e+05
# min                 0.627200       0.000000       0.000000  1.000000e+00
# ...

# %%
df.columns
# Out:
# Index(['_unit_id', '_golden', '_unit_state', '_trusted_judgments',
#        '_last_judgment_at', 'gender', 'gender:confidence', 'profile_yn',
#        'profile_yn:confidence', 'created', 'description', 'fav_number',
#        'gender_gold', 'link_color', 'name', 'profile_yn_gold', 'profileimage',
#        'retweet_count', 'sidebar_color', 'text', 'tweet_coord', 'tweet_count',
#        'tweet_created', 'tweet_id', 'tweet_location', 'user_timezone'],
#       dtype='object')

# %%
df.drop(columns = ['gender_gold','_unit_id','profile_yn_gold','profile_yn','tweet_id','link_color','profileimage','tweet_coord','fav_number','sidebar_color','tweet_created','tweet_location','user_timezone','retweet_count','tweet_count','created','_last_judgment_at'],axis = 0,inplace = True)
# all the values in gender_gold are None
# all the values in the profile_yn are same
# 19800 out of 20000 values are null

# %%
df.columns
# Out:
# Index(['_golden', '_unit_state', '_trusted_judgments', 'gender',
#        'gender:confidence', 'profile_yn:confidence', 'description', 'name',
#        'text'],
#       dtype='object')

# %%
# dependent - gender
# independent - gender:confidence, name, description,

# %%
df.isnull().sum()
# Out:
# _golden                     0
# _unit_state                 0
# _trusted_judgments          0
# gender                     97
# gender:confidence          26
# profile_yn:confidence       0
# description              3744
# name                        0
# text                        0
# dtype: int64

# %%
df.shape
# Out:
# (20050, 9)

# %%
df['bool'] = pd.get_dummies(df['_golden'],prefix="bool",drop_first = True)
df.drop(['_golden'],axis = 1,inplace = True)
df.head()
# Out:
#   _unit_state  _trusted_judgments  gender  gender:confidence  \
# 0   finalized                   3    male             1.0000
# 1   finalized                   3    male             1.0000
# 2   finalized                   3    male             0.6625
# 3   finalized                   3    male             1.0000
# 4   finalized                   3  female             1.0000
#
#    profile_yn:confidence                                        description  \
# 0                    1.0                              i sing my own rhythm.
# 1                    1.0  I'm the author of novels filled with family dr...
# 2                    1.0                louis whining and squealing and all
# 3                    1.0  Mobile guy.  49ers, Shazam, Google, Kleiner Pe...
# 4                    1.0  Ricky Wilson The Best FRONTMAN/Kaiser Chiefs T...
#
#              name                                               text  bool
# ...

# %%
df.columns
# Out:
# Index(['_unit_state', '_trusted_judgments', 'gender', 'gender:confidence',
#        'profile_yn:confidence', 'description', 'name', 'text', 'bool'],
#       dtype='object')

# %%
df['bool']
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 20045    1
# 20046    1
# 20047    1
# 20048    1
# 20049    1
# Name: bool, Length: 20050, dtype: uint8

# %%
df['unit'] = pd.get_dummies(df['_unit_state'],prefix = "unit",drop_first = True)
df.drop(['_unit_state'],axis = 1,inplace = True)
df.columns
# Out:
# Index(['_trusted_judgments', 'gender', 'gender:confidence',
#        'profile_yn:confidence', 'description', 'name', 'text', 'bool', 'unit'],
#       dtype='object')

# %%
df.head()
# Out:
#    _trusted_judgments  gender  gender:confidence  profile_yn:confidence  \
# 0                   3    male             1.0000                    1.0
# 1                   3    male             1.0000                    1.0
# 2                   3    male             0.6625                    1.0
# 3                   3    male             1.0000                    1.0
# 4                   3  female             1.0000                    1.0
#
#                                          description            name  \
# 0                              i sing my own rhythm.         sheezy0
# 1  I'm the author of novels filled with family dr...     DavdBurnett
# 2                louis whining and squealing and all  lwtprettylaugh
# 3  Mobile guy.  49ers, Shazam, Google, Kleiner Pe...     douggarland
# 4  Ricky Wilson The Best FRONTMAN/Kaiser Chiefs T...    WilfordGemma
#
#                                                 text  bool  unit
# ...

# %%
df.isnull().sum()
# Out:
# _trusted_judgments          0
# gender                     97
# gender:confidence          26
# profile_yn:confidence       0
# description              3744
# name                        0
# text                        0
# bool                        0
# unit                        0
# dtype: int64
